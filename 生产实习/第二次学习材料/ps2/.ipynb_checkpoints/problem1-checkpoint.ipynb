# %% [markdown]
# # ps1
#
# ### question1-a
#
# - 题目要求
#
# 在数据集A和B上,训练logistic回归模型最显著的区别是什么？
#
# - 思路
#
# 为了解答这个问题，我们需要通过作图来显示出A和B两个数据集的分布情况

# %% [markdown]
# 这里首先我们需要将所给的py文件函数导入进来

# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

try:
    xrange
except NameError:
    xrange = range

def add_intercept(X_):
    m, n = X_.shape
    X = np.zeros((m, n + 1))
    X[:, 0] = 1
    X[:, 1:] = X_
    return X

def load_data(filename):
    D = np.loadtxt(filename)
    Y = D[:, 0]
    X = D[:, 1:]
    return add_intercept(X), Y

def calc_grad(X, Y, theta):
    m, n = X.shape
    grad = np.zeros(theta.shape)

    margins = Y * X.dot(theta)
    probs = 1. / (1 + np.exp(margins))
    grad = -(1./m) * (X.T.dot(probs * Y))

    return grad

def logistic_regression(X, Y):
    m, n = X.shape


    theta = np.zeros(n)
    learning_rate = 10

    i = 0
    max_training_rounds = 1000000
    fig, axes = plt.subplots(2, 2, figsize=(9, 6))
    axes = axes.ravel()
    diff = []
    while True and i <= max_training_rounds:
        i += 1
        prev_theta = theta
        grad = calc_grad(X, Y, theta)
        theta = theta  - learning_rate * (grad)
        norm = np.linalg.norm(prev_theta - theta)

        diff.append(norm)

        if i % 10000 == 0:
            print('Finished {0} iterations; Diff theta: {1}; theta: {2}; Grad: {3}'.format(
                i, norm, theta, grad))

            for j in range(m):
                if Y[j] == 1:
                    axes[int(i / 10000 - 1)].scatter(X[j][1], X[j][2], color='red')
                else:
                    axes[int(i / 10000 - 1)].scatter(X[j][1], X[j][2], color='blue')
            x = np.arange(0, 1, 0.1)
            axes[int(i/10000-1)].plot(x, -(theta[0] + theta[1] * x) / theta[2])

        if norm < 1e-15:
            print('Converged in %d iterations' % i)
            break

    plt.xlabel('Training Rounds')
    plt.ylabel('Theta Difference')
    plt.plot(np.arange(i)+1,np.array(diff))

    plt.show()
    return

def main():
    print('==== Training model on data set A ====')
    Xa, Ya = load_data('./data/data_a.txt')
    logistic_regression(Xa, Ya)

    print('\n==== Training model on data set B ====')
    Xb, Yb = load_data('./data/data_b.txt')
    logistic_regression(Xb, Yb)

    return

# %% [markdown]
# 这里首先调用main函数

# %%
main()
# Out:
# ==== Training model on data set A ====
# Finished 10000 iterations; Diff theta: 7.226491864936692e-07; theta: [-20.81394174  21.45250215  19.85155266]; Grad: [ 4.15154546e-08 -4.27822247e-08 -4.08456455e-08]
# Finished 20000 iterations; Diff theta: 5.3329785269148335e-11; theta: [-20.81437785  21.45295156  19.85198173]; Grad: [ 3.06366902e-12 -3.15717192e-12 -3.01432011e-12]
# Finished 30000 iterations; Diff theta: 6.153480596427404e-15; theta: [-20.81437788  21.45295159  19.85198176]; Grad: [ 1.91127606e-16 -2.90264320e-16 -2.01301257e-16]
# Converged in 30395 iterations
# ==== Training model on data set B ====
# Finished 10000 iterations; Diff theta: 0.003361039469518825; theta: [-52.74109217  52.92982273  52.69691453]; Grad: [ 0.00019399 -0.00019355 -0.00019461]
# Finished 20000 iterations; Diff theta: 0.002173205351041188; theta: [-68.10040977  68.26496086  68.09888223]; Grad: [ 0.00012541 -0.00012529 -0.0001257 ]
# ...

# %% [markdown]
# 接下来我们需要显示出两个数据集的分布情况

# %% [markdown]
# 通过两个计算出来的分割函数发现数据集B的线性分割函数更加合适，错误率更少

# %% [markdown]
# ### question1-b
# - 题目要求
#
# 给出解释，为什么训练结果会是问题a中的这种情况
# - 思路
#
# 从做出的图形来看，B中数据集是线性可分的，但是A并不是，这会导致成本函数不会保持一致收敛，会在一定的循环次数后导致成本函数增加

# %% [markdown]
# ### question1-c
# - 题目要求
#
# 回答四个问题
#
# - 思路
#     - 问题一：不会。学习率的大小只会影响收敛速率，并不会影响收敛性
#     - 问题二：同上
#     - 问题三：引入了惩罚项防止模型过拟合，会解决这个问题
#     - 问题四：输入特征的线性缩放并不会改变数据集的线性不可分特性
#     - 问题五：这是可行的，因为数据可以通过添加噪声而线性不可分割。然而，这不是一个完全的解决方案，因为算法的收敛性取决于噪声样本集：不能保证算法在所有可能的噪声样本集上都会收敛。

# %% [markdown]
# ### question1-d
# - 题目要求
#
# 使用hinge loss的支持向量机对于B数据集来说有影响吗？
#
# - 思路
#
# 支持向量机只是找出对于最近数据点距离最大的分割线，对于数据集B来说并不会有什么区别，因为svm本质上也是通过w来对分割线进行确定的
